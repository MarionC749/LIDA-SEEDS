# %% [markdown]
# # SEEDS - 3 - Soil Health Search

# %% [markdown]
# This notebook combines and formalizes soil data in **Leeds**.
#
# The workflow is designed to be adaptable for any UK local authority, which is selected at the beginning of the notebook. However, as this project focuses on Leeds, several datasets are sourced for the region tile (not whole of UK), making parts of the analysis project-specific.
#
# Where possible, the notebook automatically retrieves the most up-to-date available data. Some datasets are however static and have not been updated for several years, these must thus be dowloaded manually.

# %%
pip install matplotlib mapclassify geopandas numpy scipy folium plotly
# Out:
# Requirement already satisfied: matplotlib in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (3.10.9)
# Requirement already satisfied: mapclassify in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (2.10.0)
# Requirement already satisfied: geopandas in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (1.1.3)
# Requirement already satisfied: numpy in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (2.4.6)
# Requirement already satisfied: scipy in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (1.17.1)
# Requirement already satisfied: folium in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (0.20.0)
# Requirement already satisfied: plotly in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (6.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: networkx>=3.2 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from mapclassify) (3.6.1)
# Requirement already satisfied: pandas>=2.1 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from mapclassify) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.4 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from mapclassify) (1.9.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from folium) (2.34.2)
# Requirement already satisfied: xyzservices in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from folium) (2026.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from plotly) (2.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: tzdata in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from pandas>=2.1->mapclassify) (2026.2)
# Requirement already satisfied: certifi in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2026.5.20)
# Requirement already satisfied: six>=1.5 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from scikit-learn>=1.4->mapclassify) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from requests->folium) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
#Import packages
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import folium
import mapclassify
import os

# %%
#Choose Local Authority to work with
LOCAL_AUTHORITY_NAME = 'Leeds' 

output_file = f'output_{LOCAL_AUTHORITY_NAME}.gpkg'

# %% [markdown]
# ## 1- Define Local Authority Boundaries

# %% [markdown]
# The UK local authorities boundaries data was downloaded from [geoportal](https://geoportal.statistics.gov.uk/datasets/ons::local-authority-districts-may-2024-boundaries-uk-bfe-2/explore?location=53.495068%2C-0.354857%2C7).
# The UK data is subsetted to only include the boundaries of the local authority chosen at the start, in the case of this study Leeds is chosen.

# %%
# Define data folder path
DATA_DIR = r'C:\Users\qxnq723\Desktop\Project_2\Datasets'

# UK local authorities file path
UK_LAD_PATH = f"{DATA_DIR}\Local_Authority_Districts_May_2024_Boundaries_UK_BFE_6583563793708892075\LAD_MAY_2024_UK_BFE.shp"

print(f"Configured for: {LOCAL_AUTHORITY_NAME}")
print(f"Data directory: {DATA_DIR}")
# Out:
# Configured for: Leeds
# Data directory: C:\Users\qxnq723\Desktop\Project_2\Datasets

# %%
# Load UK Local Authority District boundaries
print("Loading UK Local Authority District boundaries...")
LAD_2024 = gpd.read_file(UK_LAD_PATH)

print(f"Loaded {len(LAD_2024)} local authority districts")
print(f"Available LADs include: {sorted(LAD_2024['LAD24NM'].unique())[:10]}...")

# Check if our chosen LAD exists 
if LOCAL_AUTHORITY_NAME in LAD_2024['LAD24NM'].values:
    print(f"Found {LOCAL_AUTHORITY_NAME} in the dataset")
    target_lad = LAD_2024[LAD_2024['LAD24NM'] == LOCAL_AUTHORITY_NAME]
    print(f"Area: {target_lad.to_crs('EPSG:27700').geometry.area.iloc[0]/1000000:.2f} km²")
else:
    print(f"{LOCAL_AUTHORITY_NAME} not found in dataset")
    print("Available LADs:", sorted(LAD_2024['LAD24NM'].unique()))
# Out:
# Loading UK Local Authority District boundaries...
# Loaded 361 local authority districts
# Available LADs include: ['Aberdeen City', 'Aberdeenshire', 'Adur', 'Amber Valley', 'Angus', 'Antrim and Newtownabbey', 'Ards and North Down', 'Argyll and Bute', 'Armagh City, Banbridge and Craigavon', 'Arun']...
# Found Leeds in the dataset
# Area: 551.70 km²

# %%
#Keep only chosen LA and plot it
chosen_LA = LAD_2024[LAD_2024['LAD24NM'] == LOCAL_AUTHORITY_NAME]
chosen_LA.plot()
# Out:
# <Axes: >

# %%
#Check CRS
print(chosen_LA.crs)
# Out:
# EPSG:27700

# %%
#Create outline of chosen LA
chosen_LA['outline'] = 1
LA_outline = chosen_LA.dissolve(by= 'outline')

# %% [markdown]
# A function is created to subset datasets to the chosen local authority boundaries.

# %%
#Create function to subset data to the chosen LA
def subset_to_LAD(LAD_gdf, LAD_column_name, LAD_name, data_to_subset):
    """
    Subset a greenspace (or similar file) to only include greenspaces 
    within a chosen local authority.
    
    Parameters
    ----------
    LAD_gdf : geopandas.GeoDataFrame
        GeoDataFrame containing local authority district boundaries
    LAD_column_name : str
        Name of the column containing LAD names
    LAD_name : str
        Name of the specific LAD to subset to
    data_to_subset : geopandas.GeoDataFrame
        Data to be subset to the chosen LAD
        
    Returns
    -------
    geopandas.GeoDataFrame
        Data subset to only include features within the chosen LAD
    """
    chosen_LAD = LAD_gdf.loc[LAD_gdf[LAD_column_name] == LAD_name, :]
    chosen_LAD = chosen_LAD.to_crs(data_to_subset.crs)
    data_subset_to_LAD = data_to_subset[data_to_subset.within(chosen_LAD.union_all())]
    return data_subset_to_LAD

# %% [markdown]
# ## 2- Geological Data - Digimap
#
# The following geological data is downloaded from [Digimap Geology](https://digimap.edina.ac.uk/roam/map/geology).

# %% [markdown]
# ### A- Geological Indicators of Flooding (UK - 2010)

# %%
#Load file
Flood = gpd.read_file(f'{DATA_DIR}\Digimap_Geology\gi-flooding_6370739\GeologicalIndicatorsFloodingGB_v6.shp')

# %%
#Subset data to LA
flooding = gpd.clip(Flood, LA_outline)

#Check
flooding.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### B- Soil Parent (SE Tile - 2019)

# %%
#Open all shapefiles in folder

folder_path = f'{DATA_DIR}\Digimap_Geology\soil-parent_6370741\se'

gdfs = []

#Loop through all files in folder
for file in os.listdir(folder_path):
    if file.endswith('.shp'):
        shp_path = os.path.join(folder_path, file)
        gdf = gpd.read_file(shp_path)
        gdfs.append(gdf)

#Combile all shapefiles
soil_parent = gpd.GeoDataFrame(
    pd.concat(gdfs, ignore_index=True),
    crs=gdfs[0].crs
)

soil_parent.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 74201 entries, 0 to 74200
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GEN_PMLITH  74201 non-null  str
#  1   ESB_DESC    74201 non-null  str
#  2   GEN_GRAIN   74201 non-null  str
#  3   SOIL_GROUP  74201 non-null  str
#  4   SOIL_DEPTH  74201 non-null  str
#  5   CACO3_RANK  74201 non-null  str
#  6   ESB_CODE    74201 non-null  str
#  7   SIMPLE_TEX  74201 non-null  str
#  8   WATER_ERZ   74201 non-null  str
#  9   WIND_ERZ    74201 non-null  str
#  10  SOIL_WASH   74201 non-null  str
#  11  Version     74201 non-null  str
#  12  UID         74201 non-null  str
#  13  geometry    74201 non-null  geometry
# dtypes: geometry(1), str(13)
# memory usage: 7.9 MB

# %%
#Subset data to LA
soil_parent = gpd.clip(soil_parent, LA_outline)

# %%
soil_parent.head()
# Out:
#                GEN_PMLITH                ESB_DESC              GEN_GRAIN  \
# 30984  MUDSTONE-SANDSTONE  MUDSTONE AND SANDSTONE  ARGILLIC - ARENACEOUS
# 30739  MUDSTONE-SANDSTONE  MUDSTONE AND SANDSTONE  ARGILLIC - ARENACEOUS
# 34692           SANDSTONE               SANDSTONE             ARENACEOUS
# 34947           SANDSTONE               SANDSTONE             ARENACEOUS
# 31056  MUDSTONE-SANDSTONE  MUDSTONE AND SANDSTONE  ARGILLIC - ARENACEOUS
#
#             SOIL_GROUP            SOIL_DEPTH CACO3_RANK ESB_CODE  \
# 30984  HEAVY TO MEDIUM  INTERMEDIATE-SHALLOW       NONE  131_121
# 30739  HEAVY TO MEDIUM  INTERMEDIATE-SHALLOW       NONE  131_121
# 34692  MEDIUM TO HEAVY               SHALLOW       NONE      121
# 34947  MEDIUM TO HEAVY               SHALLOW       NONE      121
# 31056  HEAVY TO MEDIUM  INTERMEDIATE-SHALLOW       NONE  131_121
#
#                       SIMPLE_TEX  \
# 30984  CLAYEY LOAM TO SANDY LOAM
# 30739  CLAYEY LOAM TO SANDY LOAM
# 34692         LOAM TO SANDY LOAM
# 34947         LOAM TO SANDY LOAM
# 31056  CLAYEY LOAM TO SANDY LOAM
#
#                                                WATER_ERZ  \
# 30984  Moderate. Rills may form during very wet perio...
# 30739  Low. Sediment rarely seen to move, but be awar...
# 34692  High. Rills likely to form during very wet per...
# 34947  Low-moderate. Rarely rills may form during ver...
# 31056  Moderate. Rills may form during very wet perio...
#
#                                 WIND_ERZ  \
# 30984  Soil is not prone to wind erosion
# 30739  Soil is not prone to wind erosion
# 34692  Soil may be prone to wind erosion
# 34947  Soil may be prone to wind erosion
# 31056  Soil is not prone to wind erosion
#
#                                                SOIL_WASH Version  \
# 30984      Run off seen in some years during wet periods    v6.1
# 30739  Run off seen in some years during VERY wet per...    v6.1
# 34692      Run off seen in some years during wet periods    v6.1
# 34947  Run off seen in some years during VERY wet per...    v6.1
# 31056      Run off seen in some years during wet periods    v6.1
#
#                        UID                                           geometry
# 30984  bgsn:SPMv61_1322255  POLYGON ((428464.965 423360.581, 428468.981 42...
# 30739  bgsn:SPMv61_1319103  POLYGON ((429098 422718, 429087 422730, 429069...
# 34692  bgsn:SPMv61_1979458  POLYGON ((428975 422956.831, 428956.991 422975...
# 34947  bgsn:SPMv61_1981987  POLYGON ((431755.108 425575, 431775 425554.416...
# 31056  bgsn:SPMv61_1322347  POLYGON ((431258 425480, 431265.687 425483.048...

# %%
soil_parent['SOIL_GROUP'].value_counts()
# Out:
# SOIL_GROUP
# LIGHT(SILTY) TO MEDIUM(SILTY) TO HEAVY    1962
# MEDIUM TO HEAVY                           1520
# LIGHT(SILTY) TO MEDIUM(SILTY)             1081
# MEDIUM TO LIGHT(SILTY) TO HEAVY            702
# LIGHT(SANDY) TO MEDIUM(SANDY)              480
# HEAVY TO MEDIUM                            395
# ALL                                        346
# MEDIUM(SILTY)                               72
# MEDIUM                                      32
# MEDIUM TO LIGHT(SILTY)                      17
# Name: count, dtype: int64

# %%
soil_parent['GEN_GRAIN'].value_counts()
# Out:
# GEN_GRAIN
# ARGILLIC - ARENACEOUS         2898
# ARENACEOUS                    2640
# MIXED (ARGILLIC-RUDACEOUS)     694
# ARENACEOUS - RUDACEOUS         286
# ARGILLACEOUS                    80
# PEAT                             9
# Name: count, dtype: int64

# %%
soil_parent['ESB_DESC'].value_counts()
# Out:
# ESB_DESC
# SANDSTONE                                         2640
# MUDSTONE AND SANDSTONE                            2049
# GLACIAL TILL                                       681
# DOLOSTONE                                          314
# RIVERINE CLAY AND FLOODPLAIN SANDS AND GRAVEL      289
# COLLUVIUM                                          206
# RIVER TERRACE SAND/GRAVEL                          156
# GLACIOFLUVIAL DEPOSITS                             126
# CLAYSTONE/MUDSTONE                                  73
# LIMESTONE                                           32
# UNCONSOLIDATED FLUVIAL AND GLACIGENIC DEPOSITS      13
# PEAT                                                 9
# GLACIOLACUSTRINE                                     7
# UNCONSOLIDATED GLACIAL DEPOSITS                      5
# FLOODPLAIN SAND/GRAVEL                               4
# LACUSTRINE SAND AND SILT                             3
# Name: count, dtype: int64

# %%
soil_parent['SIMPLE_TEX'].value_counts()
# Out:
# SIMPLE_TEX
# LOAM TO SANDY LOAM           2375
# CLAYEY LOAM TO SANDY LOAM    2255
# CLAYEY LOAM TO SILTY LOAM     692
# SAND TO SANDY LOAM            395
# LOAM TO SILTY                 314
# CLAY TO SANDY LOAM            294
# SANDY LOAM                    156
# SILTY LOAM                     72
# LOAM TO SILTY LOAM             32
# VARIED, LOCALLY PEATY          13
# PEAT                            9
# Name: count, dtype: int64

# %%
#Create map of soil type

#Choose which description to map
column = 'SIMPLE_TEX'

fig, ax = plt.subplots(figsize=(10, 8))

soil_parent.plot(column = column,
                 categorical= True,
                 legend = True,
                 cmap= 'tab20',
                 edgecolor= 'black',
                 linewidth= 0.5,
                 ax= ax,
                 legend_kwds= {
                     'loc': 'upper right',
                     'bbox_to_anchor': (1.4, 0.8)
                 }
)

ax.set_title('Soil Type', fontsize= 16, fontweight= 'bold')
ax.set_axis_off()
plt.show()

# %%
#Create soil metric column
soil_parent['Soil_Metric'] = 'Soil Parent'

# %% [markdown]
# ## 3- Land cover - Digimap

# %% [markdown]
# The 2024 land cover data for the SE tile was downloaded from [Digimap Environment](https://digimap.edina.ac.uk/roam/map/environment).

# %%
#Load file
LandCover = gpd.read_file(f'{DATA_DIR}\Digimap_LandCover_SETile\lcm-2024-vec_6387524\lcm-2024-vec_6387524.gpkg')
LandCover.head()
print(LandCover.crs)
# Out:
# EPSG:27700

# %%
#Subset data to LA
LandCover = gpd.clip(LandCover, LA_outline)

# %%
#Convert the _mode to integer
LandCover['_mode'] = LandCover['_mode'].astype('Int64')

# %%
#Add column with land cover associated with each _mode

#Create list of identifiers (based on documentation)
LC_identifiers = {
    'Deciduous woodland': 1,
    'Coniferous woodland': 2,
    'Arable': 3,
    'Improve grassland': 4,
    'Neutral grassland': 5,
    'Calcareous grassland':	6,
    'Acid grassland': 7,
    'Fen': 8,
    'Heather': 9,
    'Heather grassland': 10,
    'Bog': 11,
    'Inland rock': 12,
    'Saltwater': 13,
    'Freshwater': 14,
    'Supralittoral rock': 15,
    'Supralittoral sediment': 16,
    'Littoral  rock': 17,
    'Littoral sediment': 18,
    'Saltmarsh': 19,
    'Urban': 20,
    'Suburban': 21
}

#Reverse dictionary: ID to label
id_to_label = {v: k for k, v in LC_identifiers.items()}

#Create new column
LandCover['Land_Cover_Type'] = LandCover['_mode'].map(id_to_label)
LandCover.head()
# Out:
#         _conf                       _hist  _mode   _n _purity _stdev _agg  \
# 261013  56.76    1:9,3:9,4:135,20:2,21:14      4  169   79.88  22.56    4
# 222059  57.88     1:15,3:4,4:3,20:3,21:41     21   66   62.12  19.44   10
# 147252  62.08             4:13,20:4,21:56     21   73   76.71  16.19   10
# 309443  57.64  1:9,3:36,4:49,20:12,21:175     21  281   62.28  21.82   10
# 177521  79.28                  4:71,21:43      4  114   62.28  20.26    4
#
#             gid                                           geometry  \
# 261013  5460832  MULTIPOLYGON (((424823.61 425230.08, 424825.44...
# 222059  4643857  POLYGON ((424845.391 425302.807, 424871.35 425...
# 147252  3087901  MULTIPOLYGON (((424823.222 425229.929, 424816....
# 309443  6477587  POLYGON ((424718.629 425342.699, 424723.698 42...
# 177521  3721705  POLYGON ((424931.28 425538.854, 424828.41 4254...
#
#           Land_Cover_Type
# 261013  Improve grassland
# 222059           Suburban
# 147252           Suburban
# 309443           Suburban
# 177521  Improve grassland

# %%
#Create map of land cover

fig, ax = plt.subplots(figsize=(10, 8))

LandCover.plot(column = 'Land_Cover_Type',
                 categorical= True,
                 legend = True,
                 cmap= 'tab20',
                 edgecolor= 'black',
                 linewidth= 0.5,
                 ax= ax,
                 legend_kwds= {
                     'loc': 'upper right',
                     'bbox_to_anchor': (1.4, 0.8)
                 }
)

ax.set_title('Land Cover', fontsize= 16, fontweight= 'bold')
ax.set_axis_off()
plt.show()

# %%
#Create soil metric column
LandCover['Soil_Metric'] = 'Land Cover'

# %% [markdown]
# ## 4 - Soil Chemistry (Heavy Metals UKSO Data)

# %% [markdown]
# The heavy metals data was dowloaded for the whole of the UK from the [UKSO UK topsoil geochemistry dataset](https://www.ukso.org/static-maps/uk-topsoil-geochemistry.html), which combines data from five different topsoil survey projects spanning from 1978 to 2014.

# %%
pip install rasterio
# Out:
# Requirement already satisfied: rasterio in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (1.4.4)
# Requirement already satisfied: affine in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from rasterio) (26.1.0)
# Requirement already satisfied: certifi in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from rasterio) (2026.5.20)
# Requirement already satisfied: click!=8.2.*,>=4.0 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from rasterio) (8.4.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from rasterio) (2.4.6)
# Requirement already satisfied: click-plugins in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from rasterio) (3.3.2)
# Requirement already satisfied: colorama in c:\users\qxnq723\desktop\project_2\dashboard development\venv\lib\site-packages (from click!=8.2.*,>=4.0->rasterio) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
#Build one combined dataset with all heavy metals 
# and
#Convert Geotiff raster into vector polygons geometries

#Import libraries
import rasterio #to open GeoTIFF files and raster data
from rasterio.features import shapes #to convert raster to polygons
from pathlib import Path #file/folder handling

#Create path to folder with heavy metal files
folder_path = Path(rf'{DATA_DIR}\UKSO_HeavyMetals')

#Create empty list to contain the GeoDataFrames
all_gdfs = []

#Loop through every subfolder for tif files
for tif_path in folder_path.rglob("*.tif"):
    print(f"Processing: {tif_path.name}")
    
    #Extract name of heavymetal from subfolders string
    subfolder_name = tif_path.parent.name
    metal = subfolder_name.split('geotiff_')[1].split('_v1')[0]

    #Open GeoTIFF file, and read band 1 into array 
    # (TIFF files have only 1 band)
    with rasterio.open(tif_path) as source:
        raster = source.read(1)
        
        #Convert raster data into polygons
        # s = polygon geometry
        # v = raster value
        results = (
            {'properties': {'value': v}, 
             'geometry': s}
            for s , v in shapes(raster, transform= source.transform) # convert pixel coordinates into real-world coordinates
            if v != source.nodata #skip pixels with no data
        )


        #Convert all polygon features into list and then into a GeoDataFrame
        gdf= gpd.GeoDataFrame.from_features(list(results))
        #Assign UK 27700 CRS
        gdf.set_crs(source.crs, inplace= True)
        
        #Track source file
        gdf['source_file'] = tif_path.stem
        #Add metal name column
        gdf['metal'] = metal
        #Add the GeoDataFrame into master list (1 GeoDataFrame per TIFF)
        all_gdfs.append(gdf)

#Convert into big table
HeavyMetals = pd.concat(all_gdfs, ignore_index = True)
HeavyMetals = gpd.GeoDataFrame(HeavyMetals, geometry= 'geometry')
HeavyMetals.head()
# Out:
# Processing: As_v1.tif
# Processing: Cd_v1.tif
# Processing: Cu_v1.tif
# Processing: Ni_v1.tif
# Processing: P2O5_v1.tif
# Processing: Pb_v1.tif
# Processing: Se_v1.tif
# Processing: Zr_v1.tif
#                                             geometry     value source_file  \
# 0  POLYGON ((239500 685500, 239500 685000, 240000...  13.14662       As_v1
# 1  POLYGON ((240500 685500, 240500 685000, 241000...  13.33386       As_v1
# 2  POLYGON ((239500 685000, 239500 684500, 240000...  13.33047       As_v1
# 3  POLYGON ((240000 685000, 240000 684500, 240500...  13.56266       As_v1
# 4  POLYGON ((240500 685000, 240500 684500, 241000...  13.60579       As_v1
#
#   metal
# 0    As
# 1    As
# 2    As
# 3    As
# 4    As

# %%
HeavyMetals.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5341907 entries, 0 to 5341906
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   geometry     geometry
#  1   value        float64
#  2   source_file  str
#  3   metal        str
# dtypes: float64(1), geometry(1), str(2)
# memory usage: 163.0 MB

# %%
HeavyMetals['metal'].value_counts()
# Out:
# metal
# Ni      672307
# As      672292
# Pb      672266
# Zr      672259
# Se      672245
# Cu      671982
# Cd      671776
# P2O5    636780
# Name: count, dtype: int64

# %%
#Subset data to LA
HeavyMetals = gpd.clip(HeavyMetals, LA_outline)

# %%
#Create map of heavy metal

#Choose which heavy metal to map
plot_metal = 'Cu'
#Filter dataset for that metal only
m = HeavyMetals[HeavyMetals['metal'] == plot_metal]

fig, ax = plt.subplots(figsize=(10, 8))

m.plot(column = 'value',
       legend = True,
       cmap= 'hot_r',
       edgecolor= 'black',
       linewidth= 0.5,
       ax= ax,
       legend_kwds= {'label': f'{plot_metal} Concentration (mg/kg)'}
)

ax.set_title(f'Heavy Metal Concentration Heatmap - {plot_metal}', 
             fontsize= 16, 
             fontweight= 'bold')
ax.set_axis_off()
plt.show()

# %%
#Add the unit of each heavy metal (are not all the same)
units= {
    'Ni': 'mg/kg',
    'As': 'mg/kg',
    'Pb': 'mg/kg',
    'Zr': 'mg/kg',
    'Se': 'mg/kg',
    'Cu': 'mg/kg',
    'Cd': 'mg/kg',
    'P2O5': 'w%',
}

HeavyMetals['HM_unit'] = HeavyMetals['metal'].map(units)

# %%
#Add the unit of each heavy metal (are not all the same)
name_metal= {
    'Ni': 'Nickel',
    'As': 'Arsenic',
    'Pb': 'Lead',
    'Zr': 'Zirconium',
    'Se': 'Selenium',
    'Cu': 'Copper',
    'Cd': 'Cadmium',
    'P2O5': 'Phosphorus',
}

HeavyMetals['HM_name'] = HeavyMetals['metal'].map(name_metal)

# %%
#Create soil metric column
HeavyMetals['Soil_Metric'] = 'Heavy Metals'

# %% [markdown]
# ## 5- Soil pH - UKSO

# %% [markdown]
# The UK soil pH data was dowloaded from [UKSO topsoil pH](https://catalogue.ceh.ac.uk/documents/5dd624a9-55c9-4cc0-b366-d335991073c7), which were collected and analysed in 2007.

# %%
Soil_pH = gpd.read_file(rf'{DATA_DIR}\UKSO_Soil_pH\data\CS_topsoil_pH_bulkDensity.shp')
Soil_pH.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1385 entries, 0 to 1384
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LCM_CLASS   1385 non-null   str
#  1   LCM_NUMBER  1385 non-null   int32
#  2   DOM_GRAIN   1385 non-null   str
#  3   SOIL_GROUP  1385 non-null   str
#  4   CACO3_RANK  1385 non-null   str
#  5   BULKD_07    1385 non-null   float64
#  6   BULKD_07SE  1385 non-null   float64
#  7   PH_78       1385 non-null   float64
#  8   PH_78SE     1385 non-null   float64
#  9   PH_98       1385 non-null   float64
#  10  PH_98SE     1385 non-null   float64
#  11  PH_07       1385 non-null   float64
#  12  PH_07SE     1385 non-null   float64
#  13  SHAPE_AREA  1385 non-null   float64
#  14  SHAPE_LEN   1385 non-null   float64
#  15  geometry    1385 non-null   geometry
# dtypes: float64(10), geometry(1), int32(1), str(4)
# memory usage: 167.8 KB

# %%
print(Soil_pH.crs)
# Out:
# EPSG:27700

# %%
#Subset data to LA
Soil_pH = gpd.clip(Soil_pH, LA_outline)

# %%
Soil_pH.head()
# Out:
#                    LCM_CLASS  LCM_NUMBER DOM_GRAIN  \
# 163     Broadleaved woodland           1       MUD
# 849  Arable and Horticulture           3      SAND
# 309       Improved Grassland           4       MUD
# 273       Improved Grassland           4      SAND
# 119     Broadleaved woodland           1      SAND
#
#                                  SOIL_GROUP CACO3_RANK  BULKD_07  BULKD_07SE  \
# 163                         HEAVY TO MEDIUM       NONE  0.759731    0.023147
# 849                                  MEDIUM       HIGH  1.159905    0.018035
# 309                         HEAVY TO MEDIUM       NONE  0.960654    0.018524
# 273                  MEDIUM TO LIGHT(SILTY)       NONE  0.937116    0.016865
# 119  LIGHT(SILTY) TO MEDIUM(SILTY) TO HEAVY       NONE  0.736193    0.022400
#
#         PH_78   PH_78SE     PH_98   PH_98SE     PH_07   PH_07SE   SHAPE_AREA  \
# 163  4.833214  0.099812  5.191102  0.101680  5.501506  0.063326   15000000.0
# 849  7.583729  0.085913  7.816203  0.080098  8.210084  0.069183  420000000.0
# 309  5.609945  0.054099  5.880890  0.053105  6.068252  0.036514  357000000.0
# 273  5.609945  0.054099  5.880890  0.053105  6.068252  0.036514  248000000.0
# 119  4.833214  0.099812  5.191102  0.101680  5.501506  0.063326   87000000.0
#
#      SHAPE_LEN                                           geometry
# 163    58000.0  POLYGON ((439000 428000, 439000 429000, 440000...
# 849   682000.0  POLYGON ((445000 443000, 445000 443114.7, 4450...
# 309   954000.0  MULTIPOLYGON (((425000 425000, 425745.143 4250...
# 273   674000.0  POLYGON ((428000 446000, 428000 446070.595, 42...
# 119   266000.0  MULTIPOLYGON (((428000 438000, 428000 439000, ...

# %% [markdown]
# PH_98 is the 'Mean value for soil pH in 1998 modelled by LCM_CLASS and CACO3_RANK', so that is used as pH value and is mapped.

# %%
#Create map of pH in 2007

fig, ax = plt.subplots(figsize=(10, 8))

Soil_pH.plot(column = 'PH_98',
       legend = True,
       cmap= 'hot_r',
       edgecolor= 'black',
       linewidth= 0.5,
       ax= ax,
       legend_kwds= {'label': 'pH'}
)

ax.set_title(f'pH in 2007 Heatmap', 
             fontsize= 16, 
             fontweight= 'bold')
ax.set_axis_off()
plt.show()

# %%
#Create soil metric column
Soil_pH['Soil_Metric'] = 'Soil pH'

# %% [markdown]
# ## 6- TopSoil Carbon - UKSO

# %% [markdown]
# The UK topsoil carbon was downloaded from [UKSO topsoil carbon](https://catalogue.ceh.ac.uk/documents/9e4451f8-23d3-40dc-9302-73e30ad3dd76), which was collected in 2007.

# %%
Soil_SOM = gpd.read_file(f'{DATA_DIR}/UKSO_SoilCarbon/data/9e4451f8-23d3-40dc-9302-73e30ad3dd76/CS_topsoil_carbon.shp')
Soil_SOM.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1385 entries, 0 to 1384
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LCM_CLASS   1385 non-null   str
#  1   LCM_NUMBER  1385 non-null   int32
#  2   DOM_GRAIN   1385 non-null   str
#  3   SOIL_GROUP  1385 non-null   str
#  4   CACO3_RANK  1385 non-null   str
#  5   CCONC_78    1385 non-null   float64
#  6   CCONC_78SE  1385 non-null   float64
#  7   CCONC_98    1385 non-null   float64
#  8   CCONC_98SE  1385 non-null   float64
#  9   CCONC_07    1385 non-null   float64
#  10  CCONC_07SE  1385 non-null   float64
#  11  LOI_78      1385 non-null   float64
#  12  LOI_78SE    1385 non-null   float64
#  13  LOI_98      1385 non-null   float64
#  14  LOI_98SE    1385 non-null   float64
#  15  LOI_07      1385 non-null   float64
#  16  LOI_07SE    1385 non-null   float64
#  17  CDENS_78    1385 non-null   float64
#  18  CDENS_78SE  1385 non-null   float64
#  19  CDENS_98    1385 non-null   float64
#  20  CDENS_98SE  1385 non-null   float64
#  21  CDENS_07    1385 non-null   float64
#  22  CDENS_07SE  1385 non-null   float64
#  23  SHAPE_AREA  1385 non-null   float64
#  24  SHAPE_LEN   1385 non-null   float64
#  25  geometry    1385 non-null   geometry
# dtypes: float64(20), geometry(1), int32(1), str(4)
# memory usage: 276.0 KB

# %%
print(Soil_SOM.crs)
# Out:
# EPSG:27700

# %%
#Subset data to LA
Soil_SOM = gpd.clip(Soil_SOM, LA_outline)

# %%
Soil_SOM.head()
# Out:
#                    LCM_CLASS  LCM_NUMBER DOM_GRAIN  \
# 28      Broadleaved woodland           1       MUD
# 96      Broadleaved woodland           1      SAND
# 538       Improved Grassland           4      SAND
# 543  Arable and Horticulture           3      SAND
# 223  Arable and Horticulture           3       MUD
#
#                         SOIL_GROUP CACO3_RANK   CCONC_78  CCONC_78SE  \
# 28                 HEAVY TO MEDIUM       NONE  57.224448   13.385675
# 96   LIGHT(SILTY) TO MEDIUM(SILTY)       NONE  68.209941   13.239136
# 538  LIGHT(SILTY) TO MEDIUM(SILTY)       NONE  58.828651    7.699216
# 543  LIGHT(SILTY) TO MEDIUM(SILTY)       NONE  35.747631    8.809080
# 223                HEAVY TO MEDIUM       NONE  24.762138    9.137334
#
#        CCONC_98  CCONC_98SE   CCONC_07  ...  LOI_07SE   CDENS_78  CDENS_78SE  \
# 28   100.833131   13.362104  81.514217  ...  1.640902  66.159914    3.055434
# 96   111.818624   13.216018  92.499710  ...  1.611174  66.159914    3.055434
# 538   59.179935    7.512513  60.023892  ...  1.064850  66.495364    1.619332
# 543   34.060466    7.776545  32.416605  ...  1.098951  52.520676    2.006340
# 223   23.074973    8.087917  21.431112  ...  1.172104  52.520676    2.006340
#
#       CDENS_98  CDENS_98SE   CDENS_07  CDENS_07SE    SHAPE_AREA  SHAPE_LEN  \
# 28   77.350750    3.123253  68.529984    1.754334  1.500000e+07    58000.0
# 96   77.350750    3.123253  68.529984    1.754334  8.000000e+07   274000.0
# 538  68.940971    1.554884  72.407370    0.969125  8.360000e+08  1896000.0
# 543  51.872363    1.662541  49.672538    1.074950  1.046000e+09  2114000.0
# 223  51.872363    1.662541  49.672538    1.074950  9.080000e+08  1698000.0
#
#                                               geometry
# 28   POLYGON ((439000 428000, 439000 429000, 440000...
# 96   POLYGON ((431000 445000, 431000 445931.912, 43...
# 538  MULTIPOLYGON (((423000 430000, 423000 429000, ...
# 543  POLYGON ((439551.3 425000, 439551.3 425000, 43...
# 223  MULTIPOLYGON (((430000 424000, 430177.499 4240...
#
# [5 rows x 26 columns]

# %% [markdown]
# LOI_07 is the 'Mean value for soil loss-on-ignition in 2007 modelled by LCM_CLASS and DOM_GRAIN', which corresponds to the soil organic matter (SOM).

# %%
#Create map of SOM in 2007

fig, ax = plt.subplots(figsize=(10, 8))

Soil_SOM.plot(column = 'LOI_07',
       legend = True,
       cmap= 'hot_r',
       edgecolor= 'black',
       linewidth= 0.5,
       ax= ax,
       legend_kwds= {'label': 'Loss-on-ignition (%)'}
)

ax.set_title(f'Soil Loss-In-Ignition in 2007 Heatmap', 
             fontsize= 16, 
             fontweight= 'bold')
ax.set_axis_off()
plt.show()

# %%
#Create soil metric column
Soil_SOM['Soil_Metric'] = 'Soil SOM'

# %% [markdown]
# ## 7- Create Clean Soil Health Dataset

# %% [markdown]
# The different datasets are combined into 1 clean soil health dataset:

# %%
print(soil_parent.crs)
print(LandCover.crs)
print(HeavyMetals.crs)
print(Soil_pH.crs)
print(Soil_SOM.crs)
# Out:
# EPSG:27700
# EPSG:27700
# PROJCS["OSGB36 / British National Grid",GEOGCS["OSGB36",DATUM["Ordnance_Survey_of_Great_Britain_1936",SPHEROID["Airy 1830",6377563.396,299.324964600004,AUTHORITY["EPSG","7001"]],AUTHORITY["EPSG","6277"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4277"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",49],PARAMETER["central_meridian",-2],PARAMETER["scale_factor",0.9996012717],PARAMETER["false_easting",400000],PARAMETER["false_northing",-100000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","27700"]]
# EPSG:27700
# EPSG:27700

# %%
#Set the crs to 27700
HeavyMetals = HeavyMetals.to_crs("EPSG:27700")

# %%
Soil_pH.columns
# Out:
# Index(['LCM_CLASS', 'LCM_NUMBER', 'DOM_GRAIN', 'SOIL_GROUP', 'CACO3_RANK',
#        'BULKD_07', 'BULKD_07SE', 'PH_78', 'PH_78SE', 'PH_98', 'PH_98SE',
#        'PH_07', 'PH_07SE', 'SHAPE_AREA', 'SHAPE_LEN', 'geometry',
#        'Soil_Metric'],
#       dtype='str')

# %%
soil_parent['SOIL_GROUP'].unique()
# Out:
# <StringArray>
# [                       'HEAVY TO MEDIUM',
#                         'MEDIUM TO HEAVY',
#                                     'ALL',
#         'MEDIUM TO LIGHT(SILTY) TO HEAVY',
#  'LIGHT(SILTY) TO MEDIUM(SILTY) TO HEAVY',
#           'LIGHT(SILTY) TO MEDIUM(SILTY)',
#           'LIGHT(SANDY) TO MEDIUM(SANDY)',
#                  'MEDIUM TO LIGHT(SILTY)',
#                           'MEDIUM(SILTY)',
#                                  'MEDIUM']
# Length: 10, dtype: str

# %%
soil_parent_to_join= soil_parent[['GEN_GRAIN', 'SOIL_GROUP', 'geometry', 'Soil_Metric']].copy()
LandCover_to_join= LandCover[['geometry', 'Land_Cover_Type','Soil_Metric']].copy()
HeavyMetals_to_join= HeavyMetals[['geometry', 'value', 'metal', 'HM_unit', 'HM_name', 'Soil_Metric']].copy()
Soil_pH_to_join= Soil_pH[['PH_98', 'geometry', 'Soil_Metric']]
Soil_SOM_to_join= Soil_SOM[['LOI_07', 'geometry', 'Soil_Metric']]

# Combine different soil health data
soil_health = pd.concat([soil_parent_to_join, LandCover_to_join, HeavyMetals_to_join, Soil_pH_to_join, Soil_SOM_to_join], ignore_index=True)
soil_health.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 51939 entries, 0 to 51938
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GEN_GRAIN        6607 non-null   str
#  1   SOIL_GROUP       6607 non-null   str
#  2   geometry         51939 non-null  geometry
#  3   Soil_Metric      51939 non-null  str
#  4   Land_Cover_Type  26549 non-null  str
#  5   value            18697 non-null  float64
#  6   metal            18697 non-null  str
#  7   HM_unit          18697 non-null  str
#  8   HM_name          18697 non-null  str
#  9   PH_98            43 non-null     float64
#  10  LOI_07           43 non-null     float64
# dtypes: float64(3), geometry(1), str(7)
# memory usage: 4.4 MB

# %%
soil_health['Soil_Metric'].value_counts()
# Out:
# Soil_Metric
# Land Cover      26549
# Heavy Metals    18697
# Soil Parent      6607
# Soil pH            43
# Soil SOM           43
# Name: count, dtype: int64

# %%
#Save the clean soil health datasets, to map soil health over the whole of Leeds
#Save Locally
soil_health.to_file((os.path.join(DATA_DIR, "soil_health.gpkg")), driver='GPKG')
#Save in workspace
workspace_path= r"C:\Users\qxnq723\Desktop\Project_2\Dashboard Development"
soil_health.to_file((os.path.join(workspace_path, "Data", "Processed_Data", "soil_health.gpkg")), driver='GPKG')

# %% [markdown]
# ## 8- Link Existing CGSs to their corresponding soil health

# %%
#Load the existing CGSs data
exist_CGS = gpd.read_file(r"C:\Users\qxnq723\Desktop\Project_2\Dashboard Development\Data\Processed_Data\Existing_CGSs.gpkg")
exist_CGS.head()
# Out:
#   flag                   Type                                    Name  \
# 0  FWL  Composting Collective  Chapel Allerton Composting In The Park
# 1  FWL  Composting Collective                      The Involve Centre
# 2  FWL  Composting Collective                 Friends Of Hunslet Moor
# 3  FWL  Composting Collective                          The Welcome In
# 4  FWL  Composting Collective                                Garforth
#
#   Management                                    Organisation  \
# 0        NaN                                             NaN
# 1        NaN                              The Involve Centre
# 2        NaN                     Friends of Hunslet Moor Hub
# 3        NaN  OPAL (Older People's Active Learning Centre).
# 4        NaN                               Incredible Edible
#
#                           Activity_Description Entry_Conditions  \
# 0                                          NaN              NaN
# 1                                          NaN              NaN
# 2                                          NaN              NaN
# 3  Now intergenerational with a toddler group.              NaN
# 4                                          NaN              NaN
#
#   Day_and_Time_(LGAP) Ongoing_or_set_programs?_(LGAP)  \
# 0                 NaN                             NaN
# 1                 NaN                             NaN
# 2                 NaN                             NaN
# 3                 NaN                             NaN
# 4                 NaN                             NaN
#
#   All_year_or_seasonal?_(LGAP)  ... Toilets_(LGAP) Indoor_Space_(LGAP)  \
# 0                          NaN  ...            NaN                 NaN
# 1                          NaN  ...            NaN                 NaN
# 2                          NaN  ...            NaN                 NaN
# 3                          NaN  ...            NaN                 NaN
# 4                          NaN  ...            NaN                 NaN
#
#   Indoor_Type_(LGAP) Transport_Support_(LGAP)  \
# 0                NaN                      NaN
# 1                NaN                      NaN
# 2                NaN                      NaN
# 3                NaN                      NaN
# 4                NaN                      NaN
#
#                                         Contact_Name  \
# 0  Annie Whitehead OR Lukas and Katie at The Frui...
# 1                                    Annie Whitehead
# 2                                        Sam Gilmore
# 3                                       Ellen Stoker
# 4                                      Jacky Simpson
#
#                                                Email Phone_Number_(LGAP)  \
# 0  anniewhiteheadLeeds@gmail.com | Katy.daniel@ho...                 NaN
# 1  anniewhiteheadLeeds@gmail.com |Penny@Involve.o...                 NaN
# 2                              Sgilmore51@icloud.com                 NaN
# 3                          Ellen@opal-project.org.uk                 NaN
# 4                   jacquelinesimpson@btinternet.com                 NaN
#
#   Website_Link                  id               geometry
# 0          NaN  LEEDS_392f971be18a  POINT (430790 437434)
# 1          NaN  LEEDS_5ae255dcaf6e  POINT (431182 431633)
# 2          NaN  LEEDS_102d87852220  POINT (430294 431776)
# 3          NaN  LEEDS_b12fb584bf6f  POINT (425220 439259)
# 4          NaN  LEEDS_a1254fcf6232  POINT (441097 433203)
#
# [5 rows x 25 columns]

# %%
#The existing CGSs are spatially joined to the soil health data

CGS_soil = gpd.sjoin(
    exist_CGS,
    soil_health,
    predicate='intersects',
    how='left'
)

# %%
#Keep only the CGS id, name and soil health metrics
CGS_soil = CGS_soil[['id', 
                     'Name', 
                     'GEN_GRAIN', 
                     'SOIL_GROUP',
                     'Soil_Metric',
                     'Land_Cover_Type',
                     'value',
                     'metal',
                     'HM_unit',
                     'HM_name',
                     'PH_98',
                     'LOI_07']]
CGS_soil.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5033 entries, 0 to 354
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5033 non-null   str
#  1   Name             4540 non-null   str
#  2   GEN_GRAIN        530 non-null    str
#  3   SOIL_GROUP       530 non-null    str
#  4   Soil_Metric      5029 non-null   str
#  5   Land_Cover_Type  690 non-null    str
#  6   value            3571 non-null   float64
#  7   metal            3571 non-null   str
#  8   HM_unit          3571 non-null   str
#  9   HM_name          3571 non-null   str
#  10  PH_98            119 non-null    float64
#  11  LOI_07           119 non-null    float64
# dtypes: float64(3), str(9)
# memory usage: 511.2 KB

# %%
CGS_soil.head()
# Out:
#                    id                                    Name   GEN_GRAIN  \
# 0  LEEDS_392f971be18a  Chapel Allerton Composting In The Park         NaN
# 0  LEEDS_392f971be18a  Chapel Allerton Composting In The Park  ARENACEOUS
# 0  LEEDS_392f971be18a  Chapel Allerton Composting In The Park         NaN
# 0  LEEDS_392f971be18a  Chapel Allerton Composting In The Park         NaN
# 0  LEEDS_392f971be18a  Chapel Allerton Composting In The Park         NaN
#
#                       SOIL_GROUP   Soil_Metric Land_Cover_Type      value  \
# 0                            NaN  Heavy Metals             NaN   0.267916
# 0  LIGHT(SILTY) TO MEDIUM(SILTY)   Soil Parent             NaN        NaN
# 0                            NaN    Land Cover        Suburban        NaN
# 0                            NaN  Heavy Metals             NaN  22.644390
# 0                            NaN  Heavy Metals             NaN  17.759830
#
#   metal HM_unit     HM_name  PH_98  LOI_07
# 0  P2O5      w%  Phosphorus    NaN     NaN
# 0   NaN     NaN         NaN    NaN     NaN
# 0   NaN     NaN         NaN    NaN     NaN
# 0    Ni   mg/kg      Nickel    NaN     NaN
# 0    As   mg/kg     Arsenic    NaN     NaN
